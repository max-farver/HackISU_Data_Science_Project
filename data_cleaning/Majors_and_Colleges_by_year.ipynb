# %%
import pandas as pd

# %%
full_data = pd.read_csv("DFW_fully_cleaned.csv")

# %%
full_data
# Out:
#        Year Semester College Department Course                Title  \
# 0      2016     Fall    CALS      A B E   102X  LEARNING COMMUNITIE
# 1      2017     Fall    CALS      A B E   102X  LEARNING COMMUNITIE
# 2      2015   Spring    CALS      A B E    110  EXPERNC AG&BIO ENGR
# 3      2016   Spring    CALS      A B E    110  EXPERNC AG&BIO ENGR
# 4      2017   Spring    CALS      A B E    110  EXPERNC AG&BIO ENGR
# 5      2018   Spring    CALS      A B E    110  EXPERNC AG&BIO ENGR
# 6      2014     Fall    CALS      A B E    160  SYST PROB SOLV&PROG
# 7      2015     Fall    CALS      A B E    160  SYST PROB SOLV&PROG
# 8      2015   Spring    CALS      A B E    160  SYST PROB SOLV&PROG
# 9      2016     Fall    CALS      A B E    160  SYST PROB SOLV&PROG
# 10     2016   Spring    CALS      A B E    160  SYST PROB SOLV&PROG
# 11     2017     Fall    CALS      A B E    160  SYST PROB SOLV&PROG
# 12     2017   Spring    CALS      A B E    160  SYST PROB SOLV&PROG
# ...

# %%
data_2003_full = full_data[full_data['Year'] == 2003]
data_2003_summer = data_2003_full[data_2003_full['Semester'] == 'Summer']
data_2003_fall = data_2003_full[data_2003_full['Semester'] == 'Fall']

data_2004_full = full_data[full_data['Year'] == 2004]
data_2004_spring = data_2004_full[data_2004_full['Semester'] == 'Spring']
data_2004_summer = data_2004_full[data_2004_full['Semester'] == 'Summer']
data_2004_fall = data_2004_full[data_2004_full['Semester'] == 'Fall']

data_2005_full = full_data[full_data['Year'] == 2005]
data_2005_spring = data_2005_full[data_2005_full['Semester'] == 'Spring']
data_2005_summer = data_2005_full[data_2005_full['Semester'] == 'Summer']
data_2005_fall = data_2005_full[data_2005_full['Semester'] == 'Fall']

data_2006_full = full_data[full_data['Year'] == 2006]
data_2006_spring = data_2006_full[data_2006_full['Semester'] == 'Spring']
data_2006_summer = data_2006_full[data_2006_full['Semester'] == 'Summer']
data_2006_fall = data_2006_full[data_2006_full['Semester'] == 'Fall']

data_2007_full = full_data[full_data['Year'] == 2007]
data_2007_spring = data_2007_full[data_2007_full['Semester'] == 'Spring']
data_2007_summer = data_2007_full[data_2007_full['Semester'] == 'Summer']
data_2007_fall = data_2007_full[data_2007_full['Semester'] == 'Fall']

data_2008_full = full_data[full_data['Year'] == 2008]
data_2008_spring = data_2008_full[data_2008_full['Semester'] == 'Spring']
data_2008_summer = data_2008_full[data_2008_full['Semester'] == 'Summer']
data_2008_fall = data_2008_full[data_2008_full['Semester'] == 'Fall']

data_2009_full = full_data[full_data['Year'] == 2009]
data_2009_spring = data_2009_full[data_2009_full['Semester'] == 'Spring']
data_2009_summer = data_2009_full[data_2009_full['Semester'] == 'Summer']
data_2009_fall = data_2009_full[data_2009_full['Semester'] == 'Fall']

data_2010_full = full_data[full_data['Year'] == 2010]
data_2010_spring = data_2010_full[data_2010_full['Semester'] == 'Spring']
data_2010_summer = data_2010_full[data_2010_full['Semester'] == 'Summer']
data_2010_fall = data_2010_full[data_2010_full['Semester'] == 'Fall']

data_2011_full = full_data[full_data['Year'] == 2011]
data_2011_spring = data_2011_full[data_2011_full['Semester'] == 'Spring']
data_2011_summer = data_2011_full[data_2011_full['Semester'] == 'Summer']
data_2011_fall = data_2011_full[data_2011_full['Semester'] == 'Fall']

data_2012_full = full_data[full_data['Year'] == 2012]
data_2012_spring = data_2012_full[data_2012_full['Semester'] == 'Spring']
data_2012_summer = data_2012_full[data_2012_full['Semester'] == 'Summer']
data_2012_fall = data_2012_full[data_2012_full['Semester'] == 'Fall']

data_2013_full = full_data[full_data['Year'] == 2013]
data_2013_spring = data_2013_full[data_2013_full['Semester'] == 'Spring']
data_2013_summer = data_2013_full[data_2013_full['Semester'] == 'Summer']
data_2013_fall = data_2013_full[data_2013_full['Semester'] == 'Fall']

data_2014_full = full_data[full_data['Year'] == 2014]
data_2014_spring = data_2014_full[data_2014_full['Semester'] == 'Spring']
data_2014_summer = data_2014_full[data_2014_full['Semester'] == 'Summer']
data_2014_fall = data_2014_full[data_2014_full['Semester'] == 'Fall']

data_2015_full = full_data[full_data['Year'] == 2015]
data_2015_spring = data_2015_full[data_2015_full['Semester'] == 'Spring']
data_2015_summer = data_2015_full[data_2015_full['Semester'] == 'Summer']
data_2015_fall = data_2015_full[data_2015_full['Semester'] == 'Fall']

data_2016_full = full_data[full_data['Year'] == 2016]
data_2016_spring = data_2016_full[data_2016_full['Semester'] == 'Spring']
data_2016_summer = data_2016_full[data_2016_full['Semester'] == 'Summer']
data_2016_fall = data_2016_full[data_2016_full['Semester'] == 'Fall']

data_2017_full = full_data[full_data['Year'] == 2017]
data_2017_spring = data_2017_full[data_2017_full['Semester'] == 'Spring']
data_2017_summer = data_2017_full[data_2017_full['Semester'] == 'Summer']
data_2017_fall = data_2017_full[data_2017_full['Semester'] == 'Fall']

data_2018_full = full_data[full_data['Year'] == 2018]
data_2018_spring = data_2018_full[data_2018_full['Semester'] == 'Spring']
data_2018_summer = data_2018_full[data_2018_full['Semester'] == 'Summer']

# %%
data_2003_full.to_csv("data_2003_full.csv")
data_2003_summer.to_csv("data_2003_summer.csv")
data_2003_fall.to_csv("data_2003_fall.csv")

data_2004_full.to_csv("data_2004_full.csv")
data_2004_spring.to_csv("data_2004_spring.csv")
data_2004_summer.to_csv("data_2004_summer.csv")
data_2004_fall.to_csv("data_2004_fall.csv")

data_2005_full.to_csv("data_2005_full.csv")
data_2005_spring.to_csv("data_2005_spring.csv")
data_2005_summer.to_csv("data_2005_summer.csv")
data_2005_fall.to_csv("data_2005_fall.csv")

data_2006_full.to_csv("data_2006_full.csv")
data_2006_spring.to_csv("data_2006_spring.csv")
data_2006_summer.to_csv("data_2006_summer.csv")
data_2006_fall.to_csv("data_2006_fall.csv")

data_2007_full.to_csv("data_2007_full.csv")
data_2007_spring.to_csv("data_2007_spring.csv")
data_2007_summer.to_csv("data_2007_summer.csv")
data_2007_fall.to_csv("data_2007_fall.csv")

data_2008_full.to_csv("data_2008_full.csv")
data_2008_spring.to_csv("data_2008_spring.csv")
data_2008_summer.to_csv("data_2008_summer.csv")
data_2008_fall.to_csv("data_2008_fall.csv")

data_2009_full.to_csv("data_2009_full.csv")
data_2009_spring.to_csv("data_2009_spring.csv")
data_2009_summer.to_csv("data_2009_summer.csv")
data_2009_fall.to_csv("data_2009_fall.csv")

data_2010_full.to_csv("data_2010_full.csv")
data_2010_spring.to_csv("data_2010_spring.csv")
data_2010_summer.to_csv("data_2010_summer.csv")
data_2010_fall.to_csv("data_2010_fall.csv")

data_2011_full.to_csv("data_2011_full.csv")
data_2011_spring.to_csv("data_2011_spring.csv")
data_2011_summer.to_csv("data_2011_summer.csv")
data_2011_fall.to_csv("data_2011_fall.csv")

data_2012_full.to_csv("data_2012_full.csv")
data_2012_spring.to_csv("data_2012_spring.csv")
data_2012_summer.to_csv("data_2012_summer.csv")
data_2012_fall.to_csv("data_2012_fall.csv")

data_2013_full.to_csv("data_2013_full.csv")
data_2013_spring.to_csv("data_2013_spring.csv")
data_2013_summer.to_csv("data_2013_summer.csv")
data_2013_fall.to_csv("data_2013_fall.csv")

data_2014_full.to_csv("data_2014_full.csv")
data_2014_spring.to_csv("data_2014_spring.csv")
data_2014_summer.to_csv("data_2014_summer.csv")
data_2014_fall.to_csv("data_2014_fall.csv")

data_2015_full.to_csv("data_2015_full.csv")
data_2015_spring.to_csv("data_2015_spring.csv")
data_2015_summer.to_csv("data_2015_summer.csv")
data_2015_fall.to_csv("data_2015_fall.csv")

data_2016_full.to_csv("data_2016_full.csv")
data_2016_spring.to_csv("data_2016_spring.csv")
data_2016_summer.to_csv("data_2016_summer.csv")
data_2016_fall.to_csv("data_2016_fall.csv")

data_2017_full.to_csv("data_2017_full.csv")
data_2017_spring.to_csv("data_2017_spring.csv")
data_2017_summer.to_csv("data_2017_summer.csv")
data_2017_fall.to_csv("data_2017_fall.csv")

data_2018_full.to_csv("data_2018_full.csv")
data_2018_spring.to_csv("data_2018_spring.csv")
data_2018_summer.to_csv("data_2018_summer.csv")

# %%
df = full_data.groupby(['Year', 'College'], as_index=False).mean(numeric_only=True)
df
# Out:
#      Year College  Total Grades  D, F, W Grades      % DFW
# 0    2003     BUS    147.955882       16.852941   8.235294
# 1    2003    CALS     30.131455        3.253521   9.323944
# 2    2003    DSGN     34.891566        3.909639  10.993976
# 3    2003    ENGR     54.629032        6.387097   8.763441
# 4    2003   INDIS     36.211765        4.044118   6.670588
# 5    2003     LAS     76.045113       12.320301  11.625564
# 6    2003     LIB   3556.000000      423.000000  12.000000
# 7    2004     BUS    111.759358       12.347594   7.379679
# 8    2004    CALS     27.882729        2.923241   7.953092
# 9    2004    DSGN     29.978780        3.100796   7.692308
# 10   2004    ENGR     44.761488        5.512035   8.452954
# 11   2004   INDIS     42.076606        5.202636   7.986820
# 12   2004     LAS     64.280632       10.866271  12.145586
# 13   2004     LIB   1811.333333      296.000000  16.333333
# 14   2005     BUS    102.321608       11.095477   6.678392
# ...

# %%
df.to_csv("historical_comp.csv")
