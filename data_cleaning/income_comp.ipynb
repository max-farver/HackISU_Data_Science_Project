# %%
import pandas as pd

# %%
incomes = pd.read_csv("incomes_cleaned.csv")
majors = pd.read_csv("major_rating.csv")

# %%
incomes
# Out:
#      Major_code                                              Major  \
# 0          1100                                GENERAL AGRICULTURE
# 1          1101              AGRICULTURE PRODUCTION AND MANAGEMENT
# 2          1102                             AGRICULTURAL ECONOMICS
# 3          1103                                    ANIMAL SCIENCES
# 4          1104                                       FOOD SCIENCE
# 5          1105                         PLANT SCIENCE AND AGRONOMY
# 6          1106                                       SOIL SCIENCE
# 7          1199                          MISCELLANEOUS AGRICULTURE
# 8          1301                              ENVIRONMENTAL SCIENCE
# 9          1302                                           FORESTRY
# 10         1303                       NATURAL RESOURCES MANAGEMENT
# 11         1401                                       ARCHITECTURE
# 12         1501               AREA ETHNIC AND CIVILIZATION STUDIES
# ...

# %%
majors
# Out:
#       College                                              Major  \
# 0        CALS  Agricultural and Life Sciences Education- B.S ...
# 1        CALS  Agricultural and Life Sciences Education- B.S ...
# 2        CALS  Agricultural and Life Sciences Education- B.S ...
# 3        CALS  Agricultural and Life Sciences Education- B.S ...
# 4        CALS  Agricultural and Life Sciences Education- B.S ...
# 5        CALS  Agricultural and Life Sciences Education- B.S ...
# 6        CALS  Agricultural and Life Sciences Education- B.S ...
# 7        CALS  Agricultural and Life Sciences Education- B.S ...
# 8        CALS  Agricultural and Life Sciences Education- B.S ...
# 9        CALS  Agricultural and Life Sciences Education- B.S ...
# 10       CALS  Agricultural and Life Sciences Education- B.S ...
# 11       CALS  Agricultural and Life Sciences Education- B.S ...
# 12       CALS  Agricultural and Life Sciences Education- B.S ...
# ...

# %%
for i in range(len(incomes['Major'])):
    temp = incomes.at[i, 'Major'].replace(" ", "")
    for index in range(len(majors['Major'])):
        major = majors.at[index, ['Major']].replace(" ", "")
        if temp in major:
            print(temp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-e5a1cc6dda48> in <module>()
#       2     temp = incomes.at[i, 'Major'].replace(" ", "")
#       3     for index in range(len(majors['Major'])):
# ----> 4         major = majors.at[index, ['Major']].replace(" ", "")
#       5         if temp in major:
#       6             print(temp)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2140
#    2141         key = self._convert_key(key)
# -> 2142         return self.obj._get_value(*key, takeable=self._takeable)
#    2143
#    2144     def __setitem__(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    2530             return com._maybe_box_datetimelike(series._values[index])
#    2531
# ...
