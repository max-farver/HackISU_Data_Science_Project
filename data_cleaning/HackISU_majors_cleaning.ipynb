# %%
import pandas as pd
import numpy as np

df = pd.read_csv("major_class.csv", encoding='latin-1')

# %%
df.head()
# Out:
#                                                major      class
# 0  Agricultural and Life Sciences Education- B.S ...   ENGL 150
# 1  Agricultural and Life Sciences Education- B.S ...   ENGL 250
# 2  Agricultural and Life Sciences Education- B.S ...  AGEDS 311
# 3  Agricultural and Life Sciences Education- B.S ...    LIB 160
# 4  Agricultural and Life Sciences Education- B.S ...  PSYCH 230

# %%
df.dropna()
# Out:
#                                                    major       class
# 0      Agricultural and Life Sciences Education- B.S ...    ENGL 150
# 1      Agricultural and Life Sciences Education- B.S ...    ENGL 250
# 2      Agricultural and Life Sciences Education- B.S ...   AGEDS 311
# 3      Agricultural and Life Sciences Education- B.S ...     LIB 160
# 4      Agricultural and Life Sciences Education- B.S ...   PSYCH 230
# 5      Agricultural and Life Sciences Education- B.S ...    CHEM 163
# 6      Agricultural and Life Sciences Education- B.S ...    MATH 104
# 7      Agricultural and Life Sciences Education- B.S ...    BIOL 211
# 8      Agricultural and Life Sciences Education- B.S ...    BIOL 212
# 9      Agricultural and Life Sciences Education- B.S ...    STAT 104
# 10     Agricultural and Life Sciences Education- B.S ...    ACCT 284
# 11     Agricultural and Life Sciences Education- B.S ...   AGEDS 315
# 12     Agricultural and Life Sciences Education- B.S ...   AGEDS 488
# ...

# %%
df.to_csv('major_class_cleaned.csv')
