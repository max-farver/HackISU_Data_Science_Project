# %%
import pandas as pd

# %%
df = pd.read_csv("major_class.csv", encoding='cp1252')

# %%
df[df['College'] == 'LAS']
# Out:
#       College                                              Major  \
# 18828     LAS                                  Advertising- B.A.
# 18829     LAS                                  Advertising- B.A.
# 18830     LAS                                  Advertising- B.A.
# 18831     LAS                                  Advertising- B.A.
# 18832     LAS                                  Advertising- B.A.
# 18833     LAS                                  Advertising- B.A.
# 18834     LAS                                  Advertising- B.A.
# 18835     LAS                                  Advertising- B.A.
# 18836     LAS                                  Advertising- B.A.
# 18837     LAS                                  Advertising- B.A.
# 18838     LAS                                  Advertising- B.A.
# 18839     LAS                                  Advertising- B.A.
# 18840     LAS                                  Advertising- B.A.
# ...

# %%
df = df[df['Class'] != ""]
df = df[df['Major'] != ""]
df = df[df['College'] != ""]

# %%
df[df['College'] == 'LAS']
# Out:
#       College                                              Major  \
# 18828     LAS                                  Advertising- B.A.
# 18829     LAS                                  Advertising- B.A.
# 18830     LAS                                  Advertising- B.A.
# 18831     LAS                                  Advertising- B.A.
# 18832     LAS                                  Advertising- B.A.
# 18833     LAS                                  Advertising- B.A.
# 18834     LAS                                  Advertising- B.A.
# 18835     LAS                                  Advertising- B.A.
# 18836     LAS                                  Advertising- B.A.
# 18837     LAS                                  Advertising- B.A.
# 18838     LAS                                  Advertising- B.A.
# 18839     LAS                                  Advertising- B.A.
# 18840     LAS                                  Advertising- B.A.
# ...

# %%
df.to_csv("DFW_done_cleaned.csv", index=False)
